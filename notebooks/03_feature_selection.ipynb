# %% [markdown]
# # Feature Selection

# %%
import pandas as pd

# %%
motor_data = pd.read_csv('../data/processed/processed_motor_data.csv')

features = ['temperature', 'vibration', 'current', 'voltage', 'rpm', 'load']
target = 'failure'

X = motor_data[features]
y = motor_data[target]

print(f'Features shape: {X.shape}')
print(f'Target shape: {y.shape}')
