# %% [markdown]
# # Data Loading

# %%
import pandas as pd
import os
import glob

# %%
RAW_DATA_PATH = '../data/raw/'
csv_files = glob.glob(os.path.join(RAW_DATA_PATH, '*.csv'))

dfs = []
for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)

motor_data = pd.concat(dfs, ignore_index=True)
motor_data = motor_data.sort_values('Timestamp').reset_index(drop=True)
motor_data = motor_data.drop_duplicates()

print(f'Total records: {len(motor_data)}')
print(f'Class distribution: {motor_data["Machine failure"].value_counts().to_dict()}')
motor_data.head()
# Out:
# Total records: 20000
# Class distribution: {0: 18761, 1: 1239}
#     UDI Timestamp Product ID Type of Failure  Air temperature [K]  \
# 0  8707   00:19.6     L55886               L                297.2
# 1  4378   00:19.6     L62593               L                297.4
# 2  5741   00:19.6     M20600               M                302.3
# 3  2039   00:19.6     M20622               M                296.1
# 4   500   00:19.6     L47679               L                297.5
#
#    Process temperature [K]  Rotational speed [rpm]  Torque [Nm]  \
# 0                    308.6                    1335         53.0
# 1                    308.4                    1962         37.4
# 2                    311.7                    1535         38.3
# 3                    306.1                    1418         32.1
# 4                    309.1                    1515         35.1
#
#    Tool wear [min]  Machine failure  TWF  HDF  PWF  OSF  RNF
# 0               39                0    0    0    0    0    0
# 1              159                0    0    0    0    0    0
# 2                5                0    0    0    0    0    0
# 3               12                0    0    0    0    0    0
# 4              213                0    0    0    0    0    0
