# %% [markdown]
# # Data Loading

# %%
import pandas as pd
import os
import glob

# %%
RAW_DATA_PATH = '../data/raw/'
csv_files = glob.glob(os.path.join(RAW_DATA_PATH, '*.csv'))

dfs = []
for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)

motor_data = pd.concat(dfs, ignore_index=True)
motor_data = motor_data.sort_values('Timestamp').reset_index(drop=True)
motor_data = motor_data.drop_duplicates()

print(f'Total records: {len(motor_data)}')
print(f'Class distribution: {motor_data["Machine failure"].value_counts().to_dict()}')
motor_data.head()
# Out:
# Total records: 30000
# Class distribution: {0: 24761, 1: 5239}
#     UDI Timestamp Product ID Type of Failure  Air temperature [K]  \
# 0  2915   00:19.6     H31296               H                297.1
# 1  7019   00:19.6     M21878               M                300.7
# 2    93   00:19.6     M14952               M                298.9
# 3  1380   00:19.6     M26386               M                302.1
# 4    27   00:19.6     M20010               M                299.4
#
#    Process temperature [K]  Rotational speed [rpm]  Torque [Nm]  \
# 0                    307.4                    1600         37.1
# 1                    310.7                    1377         46.7
# 2                    308.9                    1727         27.1
# 3                    313.4                    1513         16.2
# 4                    309.3                    1453         13.8
#
#    Tool wear [min]  Machine failure  TWF  HDF  PWF  OSF  RNF
# 0               28                0    0    0    0    0    0
# 1               36                0    0    0    0    0    0
# 2               37                0    0    0    0    0    0
# 3               19                0    0    0    0    0    0
# 4               22                0    0    0    0    0    0
