# %% [markdown]
# # Data Loading

# %%
import pandas as pd
import os
import glob

# %%
RAW_DATA_PATH = '../data/raw/'
csv_files = glob.glob(os.path.join(RAW_DATA_PATH, '*.csv'))

dfs = []
for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)

motor_data = pd.concat(dfs, ignore_index=True)
motor_data = motor_data.sort_values('Timestamp').reset_index(drop=True)

print(f'Total records: {len(motor_data)}')
motor_data.head()
# Out:
# Total records: 10000
#     UDI Timestamp Product ID Type of Failure  Air temperature [K]  \
# 0  3238   00:19.6     M18097               M                300.9
# 1  2729   00:19.6     L49908               L                299.7
# 2  9540   00:19.6     L56719               L                299.4
# 3  2705   00:19.6     M17564               M                299.7
# 4  6713   00:19.6     H36126               H                301.4
#
#    Process temperature [K]  Rotational speed [rpm]  Torque [Nm]  \
# 0                    309.5                    1758         26.8
# 1                    309.3                    1779         25.5
# 2                    310.8                    1424         47.7
# 3                    309.2                    1608         34.4
# 4                    310.7                    1516         36.4
#
#    Tool wear [min]  Machine failure  TWF  HDF  PWF  OSF  RNF
# 0              116                0    0    0    0    0    0
# 1              129                0    0    0    0    0    0
# 2              109                0    0    0    0    0    0
# 3               68                0    0    0    0    0    0
# 4               83                0    0    0    0    0    0
